# %% [markdown]
# # **Análisis comparativo de factores socioculturales y económicos que han afectado la longevidad de las personas en la región de América Central (AC) entre los años del 2010 al 2022**
#
# ---

# %% [markdown]
# ## Preprocesado de datos

# %%
import pandas as pd
#------------------------------------------------- LIMPIEZA DE DATOS -------------------------------------------------#
# Datos obtenidos de https://databank.worldbank.org/reports.aspx?source=world-development-indicators#
with open ("datos.csv", "r") as f: #Leemos el archivo datos.csv que contiene los datos extraidos de la fuente original
    lineas = f.read().splitlines() #Dividimos el archivo en lineas
    rangoDeLineas = lineas[:85] #Extraemos las primeras 85 lineas, el resto es info. sobre la fuente

with open("preprocesado.csv", "w") as f: #Escribimos los datos preprocesados en un archivo nuevo
    for linea in rangoDeLineas: #Escribimos las lineas del archivo datos.csv en el archivo preprocesado.csv
        f.write(linea + "\n") #Escribimos una linea por vez y añadimos un salto de linea

#Leemos el archivo preprocesado.csv
df = pd.read_csv("preprocesado.csv", sep =",") 
df = df.drop(columns=["Series Code", "Country Code"], errors="ignore") #Eliminamos las columnas que no son datos

df.columns = ['País', 'Indicador', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
df.head(10) # Muestra las primeras 10 filas del dataframe
# Out:
#      País                                          Indicador  \
# 0  Panama            Access to electricity (% of population)
# 1  Panama  Adjusted net national income per capita (curre...
# 2  Panama  Current health expenditure per capita (current...
# 3  Panama  Employment to population ratio, 15+, total (%)...
# 4  Panama                       GDP per capita (current US$)
# 5  Panama  Industry (including construction), value added...
# 6  Panama  Labor force with advanced education (% of tota...
# 7  Panama                                 Labor force, total
# 8  Panama            Life expectancy at birth, total (years)
# 9  Panama                                      Net migration
#
#                2010              2011          2012              2013  \
# 0              86.9              88.6  8.930000e+01              89.1
# 1  7015.42519401087  8352.88381575184  9.470203e+03  10522.9611933459
# 2       608.2467041      665.84649658  7.258638e+02      806.58551025
# ...

# %% [markdown]
# ---
# ### **TAREAS PARA EL PROYECTO:**
#
# 1. *Un DataFrame por Indicador:*
#
# 	**Bryan**
# 	- 'Access to electricity (% of population)',
# 	- 'Adjusted net national income per capita (current US$)'
#
# 	**Jaime**
# 	- 'Current health expenditure per capita (current US$)',
# 	- 'Employment to population ratio, 15+, total (%) (national estimate)',
#
# 	**Nery**
# 	- 'GDP per capita (current US$)',
# 	- 'Industry (including construction), value added (% of GDP)',
#
# 	**Maria Jose**
# 	- 'Labor force with advanced education (% of total working-age population with advanced education)',
# 	- 'Labor force, total',
# 	- 'Life expectancy at birth, total (years)',
#
# 	**Karen**
# 	- 'Net migration',
# 	- 'People using at least basic sanitation services (% of population)',
# 	- 'Population density (people per sq. km of land area)'
#
# 2. *Hacer los siguientes gráficos por cada indicador:*
#     - Barras
#     - Líneas
#
# ---

# %%
cantidadIndicadores = len(df['Indicador'].unique()) # cantidad de indicadores
cantidadIndicadores, df['Indicador'].unique() # imprime los indicadores
# Out:
# (12,
#  array(['Access to electricity (% of population)',
#         'Adjusted net national income per capita (current US$)',
#         'Current health expenditure per capita (current US$)',
#         'Employment to population ratio, 15+, total (%) (national estimate)',
#         'GDP per capita (current US$)',
#         'Industry (including construction), value added (% of GDP)',
#         'Labor force with advanced education (% of total working-age population with advanced education)',
#         'Labor force, total', 'Life expectancy at birth, total (years)',
#         'Net migration',
#         'People using at least basic sanitation services (% of population)',
#         'Population density (people per sq. km of land area)'],
#        dtype=object))

# %% [markdown]
# ---
# ### Bryan
# - **Access to electricity (% of population):** En español, **Acceso a la electricidad (% de población)**, mide el porcentaje de la población que tiene acceso a la electricidad. Este dato es crucial para evaluar el desarrollo y la calidad de vida en una región, ya que el acceso a la electricidad es esencial para actividades cotidianas, educación, salud y economía.
#
# Puede observarse que los países con un mayor porcentaje de acceso a la electricidad son:
# 1. Costa Rica
# 2. El Salvador
# 3. Belize
#
# Mientras que los paises con menos acceso a electricidad son:
# 1.  Nicaragua
# 2. Honduras
#
# (Datos tomando como periodo de tiempo [2010 - 2022])

# %%
# seleccione las filas que contienen el indicador "Access to electricity (% of population" 
dfAccessElectricity = df[df['Indicador'].str.contains('Access to electricity (% of population)', na=False, regex=False)] 
# eliminar la columna indicador
dfAccessElectricity  = dfAccessElectricity.drop(columns=['Indicador'])
# elegimos la columna " País" como index y eliminamos la columna "País"
dfAccessElectricity .set_index('País', inplace=True)
# mostramos los datos 
dfAccessElectricity
# Out:
#              2010  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  \
# País
# Panama       86.9  88.6  89.3  89.1  90.8  91.6  92.4  93.7  93.8  93.9  95.3
# Costa Rica     99  99.2  99.5  99.6  99.4  99.4  99.5  99.6  99.7  99.7  99.9
# El Salvador  91.6  92.6  93.7    95  95.1  95.4    96  96.8    97  97.4  99.7
# Guatemala    84.3    84  86.8  88.1  85.5  90.5  91.8  93.3  94.2  95.4  96.6
# Honduras       81  82.2  83.6  87.2  88.7    90  91.6  86.5  91.6  91.1  93.1
# Nicaragua    80.1  81.2  81.3  81.9  81.9  83.2  83.9  84.6  85.2  85.7    86
# Belize       89.9  91.7  90.9  91.1  91.5  91.8  93.3  94.2  91.7  92.7  96.8
#
#              2021  2022
# País
# Panama       95.3    95
# Costa Rica    100   100
# El Salvador  97.9   100
# Guatemala    97.9  99.1
# Honduras     94.1  94.4
# Nicaragua    86.3  86.5
# Belize       97.7  98.6

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filtrar por un indicador específico
dfAccessElectricity = df[df['Indicador'] == "Access to electricity (% of population)"]

# Reemplazar valores no numéricos (como '..') por NaN
dfAccessElectricity.replace('..', pd.NA, inplace=True)

# Convertir columnas de años a numérico
dfAccessElectricity.iloc[:, 2:] = dfAccessElectricity.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')

# Eliminar la columna "Indicador"
dfAccessElectricity = dfAccessElectricity.drop(columns=['Indicador'])

# Establecer la columna "País" como índice
dfAccessElectricity.set_index('País', inplace=True)

# Crear el gráfico
plt.figure(figsize=(12, 6))

# Iterar sobre cada país para graficar su línea
for pais in dfAccessElectricity.index:
    plt.plot(
        dfAccessElectricity.columns,          # Años (columnas)
        dfAccessElectricity.loc[pais],       # Valores del país (filas)
        marker='o', 
        label=pais
    )

# Configuración del gráfico
plt.title('Acceso a electricidad por país (% de población) [2010 - 2022]', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Acceso a electricidad (%)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.tight_layout()  # Ajustar el espacio para que todo quepa bien
plt.show()
# Out:
# C:\Users\familia\AppData\Local\Temp\ipykernel_3880\819061697.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfAccessElectricity.replace('..', pd.NA, inplace=True)

# %% [markdown]
# Este gráfico ilustra la evolución del porcentaje de acceso a la electricidad por país en Centroamérica entre 2010 y 2022.
#
# En términos generales, todos los países muestran una tendencia creciente en el acceso a la electricidad, lo que refleja un avance significativo en la cobertura de este servicio básico. Costa Rica destaca de manera sobresaliente al mantener una cobertura cercana al 100%, alcanzando el 100% desde 2021 y manteniéndolo durante 2022.
#
# El Salvador también logró llegar al 100% en 2022, uniéndose a Costa Rica en términos de cobertura total. En cambio, Honduras, que se encuentra entre los países con menos acceso, experimentó una caída notable en 2017, cuando su porcentaje de acceso pasó del 91.6% al 86.5%. Esta disminución podría estar relacionada con diversos factores, como problemas de infraestructura, interrupciones en el suministro eléctrico o desafíos en las políticas energéticas nacionales de ese año.
#
# Nicaragua, por otro lado, sigue siendo el país con el menor porcentaje de acceso a la electricidad, aunque muestra una mejora constante a lo largo del tiempo. A pesar de esto, su cobertura sigue siendo inferior al 90%, lo que subraya la necesidad de continuar trabajando en el fortalecimiento de su infraestructura eléctrica para garantizar un acceso más equitativo.
#
# En resumen, aunque hay avances en todos los países, las disparidades en el acceso a la electricidad continúan siendo notorias, con Costa Rica y El Salvador a la vanguardia, y Nicaragua enfrentando los mayores desafíos en este ámbito.

# %%
import matplotlib.pyplot as plt
# Reemplazar '..' por NaN
dfAccessElectricity.replace('..', pd.NA, inplace=True)

# Convertir todas las columnas (excepto el índice) a valores numéricos
dfAccessElectricity = dfAccessElectricity.apply(pd.to_numeric, errors='coerce')

# Calcular la media de cada fila (promedio por país)
dfAccessElectricity['Media'] = dfAccessElectricity.mean(axis=1)

# Crear el gráfico de barras horizontales para la media de cada país
dfAccessElectricity['Media'].plot(kind='barh', figsize=(10, 6))

# Añadir etiquetas y título
plt.xlabel('Promedio de acceso a electricidad (%)')
plt.ylabel('País')
plt.title('Promedio de acceso a electricidad por país (% de población) [2010 - 2022]')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Calcular describe() considerando los países
describe_por_pais = dfAccessElectricity.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count       mean       std   min     25%        50%     75%  \
# País
# Panama        14.0  91.976923  2.710990  86.9  89.675  92.188462  93.875
# Costa Rica    14.0  99.576923  0.283261  99.0  99.425  99.588462  99.700
# El Salvador   14.0  96.015385  2.406353  91.6  95.025  96.007692  97.300
# Guatemala     14.0  91.346154  5.030616  84.0  87.125  91.573077  95.100
# Honduras      14.0  88.853846  4.293217  81.0  86.675  89.426923  91.600
# Nicaragua     14.0  83.676923  2.124637  80.1  81.900  83.788462  85.575
# Belize        14.0  93.223077  2.682752  89.9  91.550  92.250000  93.975
#
#                max
# País
# Panama        95.3
# Costa Rica   100.0
# El Salvador  100.0
# Guatemala     99.1
# Honduras      94.4
# Nicaragua     86.5
# Belize        98.6

# %% [markdown]
# - **Adjusted net national income per capita (current US$):** En español, **Ingreso nacional neto ajustado per cápita (US$ corrientes)**, es una medida económica que ajusta el ingreso nacional neto (GNI) per cápita restando el consumo de capital fijo y la disminución de recursos naturales. Esta métrica proporciona una visión más precisa del ingreso disponible para los ciudadanos de un país, teniendo en cuenta el desgaste de los recursos naturales y la inversión en capital.
#
# Puede observarse que los países con un mayor Ingreso nacional neto ajustado per cápita ($) son:
# 1. Costa Rica
# 2. Panama
#
# Mientras que los paises con un menor Ingreso nacional neto ajustado per cápita ($) son:
# 1. Nicaragua
# 2. Honduras
#
# (Datos tomando como periodo de tiempo [2010 - 2022])

# %%
# seleccione las filas que contienen el indicador "Ingreso nacional neto ajustado per cápita (US$ corrientes)"
dfPerCapita = df[df['Indicador'].str.contains('Adjusted net national income per capita (current US$)', na=False, regex=False)] 
# eliminar la columna indicador
dfPerCapita  = dfPerCapita.drop(columns=['Indicador'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfPerCapita .set_index('País', inplace=True)
# Reemplazar ".." con NaN para tratar valores faltantes como vacíos
dfPerCapita.replace("..", pd.NA, inplace=True)
# Eliminar columnas completamente vacías (todas las filas NaN)
dfPerCapita = dfPerCapita.dropna(axis=1, how='all')
# mostramos los datos 
dfPerCapita
# Out:
#                          2010              2011         2012  \
# País
# Panama       7015.42519401087  8352.88381575184  9470.203419
# Costa Rica   7417.77752146118  8301.60488959396  9109.071521
# El Salvador  2646.67782274323  2931.95467368242  3010.034175
# Guatemala    2417.94636048594  2722.66306177561  2871.734302
# Honduras     1636.52385383733  1827.70996762527  1843.755074
# Nicaragua    1319.96046969527  1438.65318435535  1510.682878
# Belize       3887.56178973155  4021.23739523251  4175.999757
#
#                          2013          2014              2015  \
# País
# Panama       10522.9611933459  11017.875258  11982.0392200809
# Costa Rica   9678.35110519984   9736.609781  10446.7590407173
# El Salvador  3028.66630484378   3088.366937  3181.57824187685
# Guatemala    3004.24382352275   3212.699028  3439.84711979065
# Honduras     1805.12398632364   1869.974788  1984.10464937445
# Nicaragua    1539.99866408667   1675.731940  1774.07898220904
# ...

# %%
from pyparsing import Regex
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar por un indicador específico
dfPerCapita = df[df['Indicador'] == "Adjusted net national income per capita (current US$)"]

# Convertir columnas a numérico y calcular la media por país
dfPerCapita.iloc[:, 2:] = dfPerCapita.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# eliminar la columna indicador
dfPerCapita = dfPerCapita.drop(columns=['Indicador'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfPerCapita.set_index('País', inplace=True)

plt.figure(figsize=(12, 6))

for pais in dfPerCapita.index:
    plt.plot(dfPerCapita.columns, dfPerCapita.loc[pais], marker='o', label=pais)

plt.title('Ingreso nacional neto ajustado per cápita ($) [2010 - 2022]', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Promedio per cápita ($)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# Este gráfico ilustra la evolución del Ingreso Nacional Neto Ajustado per Cápita ($) en los países de Centroamérica entre 2010 y 2022.
#
# A lo largo de este período, Panamá y Costa Rica destacan como los países con los ingresos más altos, manteniendo una posición dominante en la región. En contraste, Nicaragua y Honduras registran los valores más bajos, evidenciando una notable disparidad económica.
#
# Aunque la mayoría de los países experimentan un crecimiento sostenido en su ingreso nacional neto ajustado per cápita, se observa una caída significativa en 2020, especialmente en Panamá, lo cual parece estar relacionado con los impactos económicos derivados de la pandemia de COVID-19.
#
# Este análisis resalta las marcadas diferencias económicas entre los países de la región, con los más desarrollados como Panamá y Costa Rica manteniendo una brecha considerable frente a los de menor ingreso.

# %%
# Reemplazar '..' por NaN
dfPerCapita.replace('..', pd.NA, inplace=True)

# Convertir todas las columnas (excepto el índice) a valores numéricos
dfPerCapita = dfPerCapita.apply(pd.to_numeric, errors='coerce')

# Calcular la media de cada fila (promedio por país)
dfPerCapita['Media'] = dfPerCapita.mean(axis=1)

# Crear el gráfico de barras horizontales para la media de cada país
dfPerCapita['Media'].plot(kind='barh', figsize=(10, 6))

# Añadir etiquetas y título
plt.xlabel('Promedio per cápita ($)')
plt.ylabel('País')
plt.title('Ingreso nacional neto ajustado per cápita ($) [2010 - 2022]')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Calcular describe() considerando los países
describe_por_pais = dfPerCapita.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count          mean          std          min           25%  \
# País
# Panama        13.0  11110.225596  1925.306342  7015.425194  10522.961193
# Costa Rica    13.0  10034.386376  1167.606556  7417.777521   9678.351105
# El Salvador   13.0   3184.603027   265.099151  2646.677823   3028.666305
# Guatemala     13.0   3430.022589   562.010420  2417.946360   3004.243824
# Honduras      13.0   1994.524786   202.095445  1636.523854   1843.755074
# Nicaragua     13.0   1630.014432   148.934461  1319.960470   1539.998664
# Belize        13.0   4514.445955   343.740798  3887.561790   4181.931579
#
#                       50%           75%           max
# País
# Panama       11110.225596  12440.269051  13342.468707
# Costa Rica   10446.759041  10833.446520  11300.935194
# El Salvador   3181.578242   3301.294487   3676.349572
# Guatemala     3439.847120   3845.299226   4308.913100
# Honduras      1994.524786   2127.093079   2407.050607
# ...

# %% [markdown]
# ---
# ### Jaime

# %% [markdown]
# - **Current health expenditure per capita (current US$):** En español, **Gasto sanitario corriente per cápita (US$ corrientes)**, este indicador podemos ver la evolución de la cantidad de dinero que se gasta en salud por persona en los paises de la región, podemos ver por la tabla que el pais con menor desembolso sanitario a sido Nicaragua, y entre los mas grandes estan Costa Rica y Panamá. que se peleaban por los puestos de 2010 a 2013, pero en 2014 Panamá da un boom creciendo mas que los demas paises.

# %%
# Seleccionar las filas que contienen el indicador "Gasto sanitario corriente per cápita (US$ corrientes)"
dfHealthExpenditure = df[df['Indicador'].str.contains('Current health expenditure per capita (current US$)', na=False, regex=False)]
# Eliminar la columna 'Indicador'
dfHealthExpenditure = dfHealthExpenditure.drop(columns=['Indicador'])
# Elegir la columna "País" como índice y eliminar la columna "País"
dfHealthExpenditure.set_index('País', inplace=True)
# Reemplazar ".." con NaN para tratar valores faltantes como vacíos
dfHealthExpenditure.replace("..", pd.NA, inplace=True)
# Eliminar columnas completamente vacías (todas las filas NaN)
dfHealthExpenditure = dfHealthExpenditure.dropna(axis=1, how='all')
dfHealthExpenditure
# Out:
#                      2010          2011        2012          2013        2014  \
# País
# Panama        608.2467041  665.84649658  725.863770  806.58551025  920.076599
# Costa Rica   654.17340088  742.14190674  776.434875  816.87872314  822.910034
# El Salvador  268.66708374   293.3677063  298.725403  321.82662964  312.867462
# Guatemala    174.79473877   190.7144928  200.335541  198.33766174  216.795044
# Honduras     163.53704834  180.58157349  182.423721  175.01651001  171.304810
# Nicaragua    115.32395172  122.53475952  130.779007  137.09841919  152.644699
# Belize        242.6184082  251.19102478  246.298172   261.2244873  296.249390
#
#                      2015           2016           2017           2018  \
# País
# Panama       982.79394531  1057.40661621  1127.68896484  1228.07336426
# Costa Rica   875.34973145   870.73840332   853.75048828   902.22119141
# El Salvador  329.44250488   337.27490234   335.73712158   345.05181885
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Filtrar por el indicador "Gasto sanitario corriente per cápita (US$ corrientes)"
dfHealthExpenditure = df[df['Indicador'] == "Current health expenditure per capita (current US$)"]

# Convertir columnas a numérico y eliminar la columna 'Indicador'
dfHealthExpenditure.iloc[:, 2:] = dfHealthExpenditure.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
dfHealthExpenditure = dfHealthExpenditure.drop(columns=['Indicador'])

# Elegir la columna "País" como índice
dfHealthExpenditure.set_index('País', inplace=True)

# Crear el gráfico usando Seaborn y Matplotlib
plt.figure(figsize=(12, 6))

for pais in dfHealthExpenditure.index:
    sns.lineplot(
        x=dfHealthExpenditure.columns, 
        y=dfHealthExpenditure.loc[pais], 
        marker='o', 
        label=pais
    )

# Configuración del gráfico
plt.title('Gasto en salud per cápita por país (US$ actuales) [2010 - 2022]', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Gasto en salud per cápita (US$)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Con este grafico podemos ver el comportamiento de gasto de salud para cada uno de los paises contemplando en el eje x los años y en el eje y el desembolso, graficamente vemos que panama y costa rica lideran los puestos y que nicaragua esta en el ultimo puesto similar al analisis anterior. podemos ver los flujos e identificar la tremenda brecha entre los paises de la region central y como estos afrontan esa dificultad.

# %%
import matplotlib.pyplot as plt
# Convertir todas las columnas (excepto el índice) a valores numéricos
dfHealthExpenditure = dfHealthExpenditure.apply(pd.to_numeric, errors='coerce')

# Calcular la media de cada fila (promedio por país)
dfHealthExpenditure['Media'] = dfHealthExpenditure.mean(axis=1)

# Crear el gráfico de barras horizontales para la media de cada país
dfHealthExpenditure['Media'].plot(kind='barh', figsize=(10, 6))

# Añadir etiquetas y título
plt.xlabel('Gasto en salud per cápita (US$)')
plt.ylabel('País')
plt.title('Gasto en salud per cápita por país (US$)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# Mediante el grafico de barras se puede visualizar la distribución de los datos, aca vemos como se distribuyen los valores de la tabla de desembolsos y notamos lo que mencionamos antes, los paises de costa rica y panama liderando y Nicaragua en el puesto mas bajo

# %%
# Calcular describe() considerando los países
describe_por_pais = dfHealthExpenditure.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count         mean         std         min         25%  \
# País
# Panama        13.0  1019.671290  268.901758  608.246704  806.585510
# Costa Rica    13.0   844.290634   84.295267  654.173401  816.878723
# El Salvador   13.0   334.723913   42.710210  268.667084  312.867462
# Guatemala     13.0   241.672955   46.515779  174.794739  200.335541
# Honduras      13.0   184.621340   24.053387  163.537048  171.304810
# Nicaragua     13.0   154.490619   22.993682  115.323952  137.098419
# Belize        13.0   277.872744   21.331194  242.618408  261.224487
#
#                      50%          75%          max
# País
# Panama       1019.671290  1228.073364  1415.244995
# Costa Rica    853.750488   902.221191   953.082520
# El Salvador   334.723913   345.051819   442.213745
# Guatemala     241.672955   265.747345   340.958130
# Honduras      177.646667   184.039185   253.918045
# Nicaragua     161.199814   167.370361   198.077927
# ...

# %% [markdown]
# - **Employment to population ratio, 15+, total (%) (national estimate):** En español, **Relación empleo-población, 15+, total (%) (estimación nacional)**, acá ocurre algo, y es que los países de Nicaragua y Belice no proporcionan datos, por tanto su gráfica podría ser irregular, en un gráfico de cajas y bigotes eso se denotaría como unos datos atipicos, pero volviendo al punto del indicador, estamos hablando de una tasa de empleo nacional de 15 años o más, en donde vemos que esta tasa indicaría que en un país cierto porcentaje de la población empieza a trabajar a temprana edad, en donde por la poca información proporcionada vemos que Nicaragua se lleva esa información para un par de años, pero en medias de tiempo exactas vemos que este puesto esta para Panamá y Guatemala.

# %%
# Seleccionar las filas que contienen el indicador "Relación empleo-población, 15+, total (%) (estimación nacional)"
dfEmploymentRatio = df[df['Indicador'].str.contains('Employment to population ratio, 15+, total (%) (national estimate)', na=False, regex=False)]
# Eliminar la columna 'Indicador'
dfEmploymentRatio = dfEmploymentRatio.drop(columns=['Indicador'])
# Elegir la columna "País" como índice y eliminar la columna "País"
dfEmploymentRatio.set_index('País', inplace=True)
# Reemplazar ".." con NaN para tratar valores faltantes como vacíos
dfEmploymentRatio.replace("..", pd.NA, inplace=True)
# Eliminar columnas completamente vacías (todas las filas NaN)
dfEmploymentRatio = dfEmploymentRatio.dropna(axis=1, how='all')
dfEmploymentRatio
# Out:
#                2010    2011    2012    2013    2014    2015    2016    2017  \
# País
# Panama       59.391  59.077  60.790  61.487  60.933  60.898  60.851   60.06
# Costa Rica   54.968   54.85  58.472   58.43  58.734  57.523  54.861  55.223
# El Salvador  58.103   58.55  59.400  59.878  58.397   57.77  57.892  57.569
# Guatemala    58.345  58.867  63.318  58.404  59.082  59.077  59.122  59.443
# Honduras     59.364  57.054  56.208  59.123  59.612  60.152  59.063  60.802
# Nicaragua     68.09    <NA>  72.947   71.72  62.034    <NA>    <NA>    <NA>
# Belize         <NA>    <NA>  57.800  57.402  58.258  58.678  59.752  59.811
#
#                2018    2019    2020    2021    2022
# País
# Panama       61.463  61.817  51.296  53.504  57.727
# Costa Rica   56.604  57.318  50.666  52.416  54.527
# El Salvador  57.428  58.212  56.278  57.004  58.674
# Guatemala    59.122  57.871    <NA>  61.569  58.403
# Honduras     62.736  59.578  52.961  55.526  53.492
# ...

# %%
# Filtrar por el indicador "Relación empleo-población, 15+, total (%) (estimación nacional)"
dfEmploymentRatio = df[df['Indicador'] == "Employment to population ratio, 15+, total (%) (national estimate)"]

# Convertir columnas a numérico y eliminar la columna 'Indicador'
dfEmploymentRatio.iloc[:, 2:] = dfEmploymentRatio.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
dfEmploymentRatio = dfEmploymentRatio.drop(columns=['Indicador'])

# Elegir la columna "País" como índice
dfEmploymentRatio.set_index('País', inplace=True)

# Crear el gráfico usando Seaborn y Matplotlib
plt.figure(figsize=(12, 6))

for pais in dfEmploymentRatio.index:
    sns.lineplot(
        x=dfEmploymentRatio.columns, 
        y=dfEmploymentRatio.loc[pais], 
        marker='o', 
        label=pais
    )

# Configuración del gráfico
plt.title('Tasa de empleo por país (% de población 15+) [2010 - 2022]', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Tasa de empleo (%)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# En esta ocasion estamos viendo el grafico respecto a la tas de empleo para los paises de una edad mayor o igual a 15 años, en la figura vemos que nicaragua lidera este grupo pero por la falta de informacion no sabemos su comportamiento para el resto de los periodos, esto implica que este pais recibe personas al ambiente laboral desde temprana edad, quien sabe en que trabajo contraten a menores para algunas tareas y estos cuanto tiempo realizan sus actividades en su vida, pudiendo esforzarse tanto en tan temprana edad afectando su salud y bienestar, pasando de lado los que sabemos de nicaragua, otros paises que podriamos decir que lideran este indicador son Panama y Guatemala, en donde si bien panama de 2019 en adelante bajo este indicador, representa una tasa similar o una tendencia similar a la de GUatemala, no tan cercana pero lo suficiente para intuir que ambos paises cada año contratan a gente de 15 años o mas para distintas labores que a su vez pueden afectar su salud y longevidad.

# %%
import matplotlib.pyplot as plt
# Convertir todas las columnas (excepto el índice) a valores numéricos
dfEmploymentRatio = dfEmploymentRatio.apply(pd.to_numeric, errors='coerce')

# Calcular la media de cada fila (promedio por país)
dfEmploymentRatio['Media'] = dfEmploymentRatio.mean(axis=1)

# Crear el gráfico de barras horizontales para la media de cada país
dfEmploymentRatio['Media'].plot(kind='barh', figsize=(10, 6))

# Añadir etiquetas y título
plt.xlabel('Tasa de empleo (%)')
plt.ylabel('País')
plt.title('Tasa de empleo por país (% de la población 15+)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# Nuevamente, en este grafico vemos un promedio respecto a la cantidad de años de la tasa que involucra la tasa de empleo de personas de 15 años o mas, vemos que en promedio nicaragua realiza la mayor tas con cerca de un 70% y guatemala, panama y belice con cerca de un 60%.
# En el grafico podemos interpretar que para un periodo de 12 años la tasa de empleo es mayor a 50% para todos los paises de centroamerica, siendo asi que para una poblacion, una persona de 15 años podria ser contratado con un alto porcentaje de certeza.

# %%
# Calcular describe() considerando los países
describe_por_pais = dfEmploymentRatio.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count       mean       std     min        25%        50%  \
# País
# Panama        14.0  59.176462  3.115865  51.296  59.101865  60.425000
# Costa Rica    14.0  55.737846  2.333261  50.666  54.852750  55.480423
# El Salvador   14.0  58.088846  0.915214  56.278  57.619250  58.095923
# Guatemala     13.0  59.385250  1.475791  57.871  58.404000  59.082000
# Honduras      14.0  58.128538  2.773194  52.961  56.419500  59.093000
# Nicaragua      5.0  68.697750  4.241611  62.034  68.090000  68.697750
# Belize         8.0  59.302143  1.879036  57.402  58.143500  58.990071
#
#                   75%     max
# País
# Panama       60.92425  61.817
# Costa Rica   57.47175  58.734
# El Salvador  58.51175  59.878
# Guatemala    59.38525  63.318
# Honduras     59.60350  62.736
# Nicaragua    71.72000  72.947
# Belize       59.76675  63.414

# %% [markdown]
# ---
# ### Nery

# %% [markdown]
# - **GDP per capita (current US$):** En español, **PIB per cápita**. Representa la cantidad de dinero que le correspondería a cada habitante del país si se repartiera a todos por igual el PIB generado en un año

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filtrar por un indicador específico
dfGPD = df[df['Indicador'].str.contains('GDP per capita (current US$)', na=False, regex=False)]

# Reemplazar ".." por NaN para tratar valores faltantes
dfGPD.replace("..", pd.NA, inplace=True)

# Convertir columnas a numérico y calcular la media por país
dfGPD.iloc[:, 2:] = dfGPD.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# eliminar la columna indicador
dfGPD = dfGPD.drop(columns=['Indicador'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfGPD.set_index('País', inplace=True)


plt.figure(figsize=(12, 6))

for pais in dfGPD.index:
    plt.plot(dfGPD.columns,
              dfGPD.loc[pais],
            marker='o', 
            label=pais)

plt.title('PIB per cápita (US$ actuales) por País (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('PIB per cápita (US$)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.3)
plt.show()
# Out:
# C:\Users\familia\AppData\Local\Temp\ipykernel_3880\2583401847.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfGPD.replace("..", pd.NA, inplace=True)

# %% [markdown]
# Este gráfico muestra la evolución del Producto Interno Bruto (PIB) per cápita en dólares actuales de los países de Centroamérica entre 2010 y 2022.
#
# Panamá y Costa Rica son los países con el PIB per cápita más alto en la región durante todo el período, destacando significativamente sobre el resto. Países como Nicaragua y Honduras tienen los valores más bajos.
#
# Todos los países muestran una tendencia al alza en el PIB per cápita, lo que sugiere un crecimiento económico general durante este período. Sin embargo, en 2020, hay una caída notable en la mayoría de los países (especialmente en Panamá), probablemente relacionada con los efectos económicos de la pandemia de COVID-19.
#
# Las disparidades en PIB per cápita son claras, mostrando que los países más desarrollados económicamente, como Panamá y Costa Rica, mantienen una brecha significativa con respecto a los países de menor ingreso.

# %%
#convertir todos los datos tipo float
dfGPD = dfGPD.astype(float)
#reemplazar los valores nulos en la fila 'Nicaragua' por el promedio de los datos de esta
dfGPD.replace(0, dfGPD.iloc[5].mean(), inplace=True)
dfGPD
# Out:
#                     2010         2011          2012          2013  \
# País
# Panama       8124.558307  9403.439908  10767.293179  11932.286221
# Costa Rica   8147.243985  9137.455101   9971.651656  10633.266550
# El Salvador  3017.307395  3304.974183   3471.051269   3555.162100
# Guatemala    2852.557593  3228.038278   3355.034777   3522.767429
# Honduras     1874.271704  2053.959695   2107.345428   2064.550536
# Nicaragua    1495.729190  1644.799354   1746.418584   1794.779965
# Belize       5399.062096  5519.339008   5635.521526   5865.470902
#
#                      2014          2015          2016          2017  \
# País
# Panama       12837.247958  13669.559442  14382.232382  15185.972481
# Costa Rica   10737.678881  11529.955173  11899.813983  12118.133625
# El Salvador   3638.517658   3761.513680   3870.312982   3986.049014
# Guatemala     3779.626205   3994.629085   4173.281349   4454.024509
# Honduras      2164.424550   2257.225284   2295.536270   2403.306088
# ...

# %%
# Calcular describe() considerando los países
describe_por_pais = dfGPD.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count          mean          std          min           25%  \
# País
# Panama        13.0  13467.211349  2805.636392  8124.558307  11932.286221
# Costa Rica    13.0  11336.642459  1527.358958  8147.243985  10633.266550
# El Salvador   13.0   3895.344284   543.817286  3017.307395   3555.162100
# Guatemala     13.0   4123.546329   758.307439  2852.557593   3522.767429
# Honduras      13.0   2325.721487   305.538192  1874.271704   2107.345428
# Nicaragua     13.0   1916.068930   207.787806  1495.729190   1794.779965
# Belize        13.0   5928.036447   442.842218  5185.158070   5635.521526
#
#                       50%           75%           max
# País
# Panama       13669.559442  15491.289801  17357.628629
# Costa Rica   11899.813983  12383.149952  13365.356399
# El Salvador   3870.312982   4145.862351   5048.443973
# Guatemala     4173.281349   4609.897258   5473.208564
# Honduras      2295.536270   2457.686042   3012.217341
# ...

# %%
dfGPD_media = dfGPD.groupby('País').mean().mean(axis=1)

# Crear gráfica
plt.figure(figsize=(12, 6))
sns.barplot(y=dfGPD_media.index, x=dfGPD_media.values)

plt.title('Media del PIB per cápita (US$ actuales) por País (2010-2022)', fontsize=14)
plt.ylabel('País', fontsize=12)
plt.xlabel('PIB per cápita (US$)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

plt.show()

# %% [markdown]
# - **Industry (including construction), value added (% of GDP):** En español, **Industria (incluida la construcción), valor agregado (% del PIB)** Se refiere al poncentaje del PIB que aporta el ramo de la industria en general y la construcción a un país

# %%
# Filtrar por un indicador específico
dfIndustry = df[df['Indicador'] == "Industry (including construction), value added (% of GDP)"]

# Convertir columnas a numérico y calcular la media por país
dfIndustry.iloc[:, 2:] = dfIndustry.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# eliminar la columna indicador
dfIndustry = dfIndustry.drop(columns=['Indicador'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfIndustry.set_index('País', inplace=True)
#dfIndustry

plt.figure(figsize=(12, 6))

for pais in dfIndustry.index:
    plt.plot(dfIndustry.columns, dfIndustry.loc[pais], marker='o', label=pais)

plt.title('Porcentaje de Industrialización por País (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Porcentaje de Industrialización (%)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.show()

# %%
#convertir todos los datos tipo float
dfIndustry = dfIndustry.astype(float)
#reemplazar los valores nulos en la fila 'Nicaragua' por el promedio de los datos de esta
dfIndustry.replace(0, dfIndustry.iloc[5].mean(), inplace=True)
dfIndustry
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# País
# Panama       19.209040  19.837190  21.535378  25.137529  26.634592  27.559083
# Costa Rica   23.322965  22.589871  22.204877  21.344972  20.616405  19.967878
# El Salvador  25.275912  26.195413  26.589358  26.121643  26.013534  25.288930
# Guatemala    27.491827  27.943621  28.123437  22.952948  23.192717  22.737511
# Honduras     25.587131  25.814216  26.113572  25.409320  24.510779  25.649971
# Nicaragua    21.968757  23.157467  24.547870  25.387344  25.098653  25.734886
# Belize       18.117327  18.731288  15.836123  15.802476  15.909725  14.852258
#
#                   2016       2017       2018       2019       2020       2021  \
# País
# Panama       28.440561  29.352256  28.271584  28.387450  23.319030  26.218536
# Costa Rica   19.650011  19.314540  19.558143  19.233657  20.367851  20.605792
# El Salvador  24.834828  25.171473  25.075507  25.348144  23.724750  24.104901
# ...

# %%
# Calcular describe() considerando los países
describe_por_pais = dfIndustry.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count       mean       std        min        25%        50%  \
# País
# Panama        13.0  25.390123  3.392273  19.209040  23.319030  26.218536
# Costa Rica    13.0  20.724877  1.299525  19.233657  19.650011  20.605792
# El Salvador   13.0  25.304185  0.808924  23.724750  25.075507  25.275912
# Guatemala     13.0  23.665812  2.435040  21.426432  22.333352  22.649551
# Honduras      13.0  25.835002  0.591744  24.510779  25.587131  25.820159
# Nicaragua     13.0  24.969497  1.323335  21.968757  24.547870  25.098653
# Belize        13.0  15.924932  1.444766  13.937973  14.852258  15.802476
#
#                    75%        max
# País
# Panama       28.271584  29.352256
# Costa Rica   21.344972  23.322965
# El Salvador  26.013534  26.589358
# Guatemala    23.192717  28.123437
# Honduras     26.113572  26.724317
# Nicaragua    25.734886  27.194293
# Belize       16.596979  18.731288

# %% [markdown]
# Este gráfico representa el porcentaje de industrialización (como parte del PIB) de los países de Centroamérica entre 2010 y 2022.
#
# Panamá muestra un aumento significativo en el porcentaje de industrialización hasta 2013, seguido por una estabilización y pequeñas fluctuaciones en los años posteriores. Honduras, El Salvador y Guatemala mantienen porcentajes relativamente estables y altos de industrialización, destacando por encima del 25% durante la mayoría del período.
# Costa Rica presenta una tendencia a la baja desde 2010, lo que podría indicar una transición económica hacia sectores menos industrializados.

# %%
dfIndustry_media = dfIndustry.groupby('País').mean().mean(axis=1)

# Crear gráfica
plt.figure(figsize=(12, 6))
sns.barplot(y=dfIndustry_media.index, x=dfIndustry_media.values)

plt.title('Media de Industria (incluida la construcción), valor agregado (% del PIB) por País (2010-2022)', fontsize=14)
plt.ylabel('País', fontsize=12)
plt.xlabel('Porcentaje de Industrialización (%)', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ---
# ### Maria Jose
#
# - **Labor force with advanced education**: En español, **Fuerza laboral con educación avanzada**. El indicador "Población laboral con educación avanzada" se refiere al porcentaje de la fuerza laboral total que ha alcanzado niveles educativos superiores, como títulos universitarios o postgrados. Este indicador es importante para medir el nivel de educación en la población activa de un país o región, y está relacionado con el tipo de trabajo que las personas pueden realizar y su acceso a mejores oportunidades laborales.

# %%
# seleccione las filas que contienen el indicador "Fuerza laboral con educación avanzada" 
dfLaborForce = df[df['Indicador'].str.contains('Labor force with advanced education', na=False)] 
# eliminar la columna indicador
dfLaborForce = dfLaborForce.drop(columns=['Indicador'])
# elegimos la columna " País" como index y eliminamos la columna "País"
dfLaborForce.set_index('País', inplace=True)
# mostramos los datos 
dfLaborForce
# Out:
#                2010    2011    2012    2013    2014    2015    2016    2017  \
# País
# Panama       83.935   83.58  83.564  83.183  82.407  84.264  82.129  82.283
# Costa Rica    75.15  74.622  78.479  80.228  78.805  78.935  75.476   75.64
# El Salvador  88.485  86.659  86.049  88.687  87.390  84.195  84.345  82.344
# Guatemala    87.561  85.821  87.251  85.845  79.639  85.211  82.561    82.1
# Honduras     89.467  87.715  83.379  88.862  86.198  85.718   86.74  83.604
# Nicaragua        ..      ..  89.965      ..  85.640      ..      ..      ..
# Belize           ..      ..  87.710  83.753  85.712   85.64  84.545   82.79
#
#                2018    2019    2020    2021    2022
# País
# Panama       83.466  84.929  80.542  79.377  79.159
# Costa Rica   75.777  79.726  77.809  77.789   74.54
# El Salvador  85.487  82.694  80.301  84.883    83.6
# Guatemala    81.981  81.434      ..  84.594  81.226
# Honduras     86.308  83.443      ..  84.298  76.802
# ...

# %%
# Reemplazar los valores no numéricos por NaN
dfLaborForce.replace('..', pd.NA, inplace=True)

# Convertir las columnas a float, ignorando los errores
dfLaborForce = dfLaborForce.apply(pd.to_numeric, errors='coerce')
dfLaborForce
# Out:
#                2010    2011    2012    2013    2014    2015    2016    2017  \
# País
# Panama       83.935  83.580  83.564  83.183  82.407  84.264  82.129  82.283
# Costa Rica   75.150  74.622  78.479  80.228  78.805  78.935  75.476  75.640
# El Salvador  88.485  86.659  86.049  88.687  87.390  84.195  84.345  82.344
# Guatemala    87.561  85.821  87.251  85.845  79.639  85.211  82.561  82.100
# Honduras     89.467  87.715  83.379  88.862  86.198  85.718  86.740  83.604
# Nicaragua       NaN     NaN  89.965     NaN  85.640     NaN     NaN     NaN
# Belize          NaN     NaN  87.710  83.753  85.712  85.640  84.545  82.790
#
#                2018    2019    2020    2021    2022
# País
# Panama       83.466  84.929  80.542  79.377  79.159
# Costa Rica   75.777  79.726  77.809  77.789  74.540
# El Salvador  85.487  82.694  80.301  84.883  83.600
# Guatemala    81.981  81.434     NaN  84.594  81.226
# Honduras     86.308  83.443     NaN  84.298  76.802
# ...

# %%
#cambiar filas por columnas de un dataframe
dfLaborForce.T
# Out:
# País  Panama  Costa Rica  El Salvador  Guatemala  Honduras  Nicaragua  Belize
# 2010  83.935      75.150       88.485     87.561    89.467        NaN     NaN
# 2011  83.580      74.622       86.659     85.821    87.715        NaN     NaN
# 2012  83.564      78.479       86.049     87.251    83.379     89.965  87.710
# 2013  83.183      80.228       88.687     85.845    88.862        NaN  83.753
# 2014  82.407      78.805       87.390     79.639    86.198     85.640  85.712
# 2015  84.264      78.935       84.195     85.211    85.718        NaN  85.640
# 2016  82.129      75.476       84.345     82.561    86.740        NaN  84.545
# 2017  82.283      75.640       82.344     82.100    83.604        NaN  82.790
# 2018  83.466      75.777       85.487     81.981    86.308        NaN     NaN
# 2019  84.929      79.726       82.694     81.434    83.443        NaN  85.427
# 2020  80.542      77.809       80.301        NaN       NaN        NaN     NaN
# ...

# %%
import matplotlib.pyplot as plt
dfLaborForceMean = dfLaborForce.T.mean() #cambiamos filas por columnas y calculamos la media de cada país
#grafico de barrasa
dfLaborForceMean.plot(kind='barh', title='Media de Fuerza laboral con educación avanzada', figsize=(5,5), xlabel='País', ylabel='Media de Fuerza laboral con educación avanzada')
# Out:
# <Axes: title={'center': 'Media de Fuerza laboral con educación avanzada'}, xlabel='País', ylabel='Media de Fuerza laboral con educación avanzada'>

# %%
# Calcular describe() considerando los países en lugar de los años
describe_por_pais = dfLaborForce.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count       mean       std     min       25%      50%       75%  \
# País
# Panama        13.0  82.524462  1.818971  79.159  82.12900  83.1830  83.58000
# Costa Rica    13.0  77.152000  2.016893  74.540  75.47600  77.7890  78.80500
# El Salvador   13.0  85.009154  2.467174  80.301  83.60000  84.8830  86.65900
# Guatemala     12.0  83.768667  2.597233  79.639  81.84425  83.5775  85.82700
# Honduras      12.0  85.211167  3.345216  76.802  83.56375  85.9580  86.98375
# Nicaragua      2.0  87.802500  3.058237  85.640  86.72125  87.8025  88.88375
# Belize         7.0  85.082429  1.583327  82.790  84.14900  85.4270  85.67600
#
#                 max
# País
# Panama       84.929
# Costa Rica   80.228
# El Salvador  88.687
# Guatemala    87.561
# Honduras     89.467
# Nicaragua    89.965
# Belize       87.710

# %%
# Transponer para graficar evolución temporal por país
dfLaborForceT = dfLaborForce.T

# Crear el gráfico de líneas
plt.figure(figsize=(12, 6))

for pais in dfLaborForceT.columns:
    plt.plot(dfLaborForceT.index, dfLaborForceT[pais], marker='o', label=pais)

plt.title('Fuerza laboral con educación avanzada por País (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Porcentaje de Fuerza Laboral con Educación Avanzada (%)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# El gráfico ayuda a visualizar la relación entre el nivel educativo de la fuerza laboral y la evolución temporal, lo que puede ser relevante en el análisis de cómo la educación influye en las condiciones laborales, la calidad de vida y, en última instancia, en la longevidad de las personas en América Central.
#
# **Tendencias de crecimiento o declive :** Nos permitirá identificar si la proporción de trabajadores con educación avanzada ha aumentado o disminuido en los países durante el período de tiempo analizado.
#
# **Desigualdades entre países :** Podemos observar diferencias en la tasa de trabajadores con educación avanzada entre países de la región. Algunos países pueden mostrar un aumento más pronunciado, mientras que otros pueden estar rezagados.
#
# **Impacto socioeconómico :** Un aumento en la proporción de trabajadores con educación avanzada generalmente refleja mejoras en el acceso a la educación superior y, en muchos casos, se correlaciona con mayores oportunidades de empleo bien remunerado, lo que puede tener un efecto positivo en la calidad de vida y la longevidad.

# %% [markdown]
# - **Labor force, total**: En español, **Total de la fuerza laboral**. El indicador "Labor force, total" representa el número total de personas económicamente activas en un país o región. Esto incluye tanto a las personas empleadas como a aquellas que están desempleadas pero buscan trabajo activamente. Es un indicador clave en el análisis de la población en edad de trabajar y la participación en la economía.

# %%
# seleccionar las filas que contienen el indicador "Labor force, total"
dfLaborForceTotal = df[df['Indicador'].str.contains('Labor force, total', na=False)]

# eliminar la columna indicador
dfLaborForceTotal = dfLaborForceTotal.drop(columns=['Indicador'])

# elegimos la columna "País" como index y eliminamos la columna "País"
dfLaborForceTotal.set_index('País', inplace=True)

# mostramos los datos
dfLaborForceTotal
# Out:
#                 2010     2011       2012     2013       2014     2015  \
# País
# Panama       1618269  1611450  1689370.0  1744928  1778532.0  1813736
# Costa Rica   2060686  2149242  2321866.0  2337155  2395003.0  2380187
# El Salvador  2494725  2517133  2579866.0  2630753  2617260.0  2618193
# Guatemala    5253574  5486770  5980602.0  5682211  5883588.0  6022488
# Honduras     3260247  3243536  3268694.0  3613486  3810624.0  3919626
# Nicaragua    2442683  2512841  2583025.0  2652874  2722579.0  2784302
# Belize        128753   133836   138977.0   144234   151065.0   156821
#
#                 2016     2017     2018     2019     2020     2021     2022
# País
# Panama       1859078  1885561  1966334  2041466  1929211  1996749  2049663
# Costa Rica   2296246  2335223  2459739  2573190  2456537  2529009  2542517
# El Salvador  2673318  2687119  2694155  2762085  2632889  2768977  2835063
# Guatemala    6184488  6364813  6472399  6481136  6460734  6764382  7069008
# ...

# %%
# Reemplazar los valores no numéricos por NaN
dfLaborForceTotal.replace('..', pd.NA, inplace=True)

# Convertir los datos a tipo float
dfLaborForceTotal = dfLaborForceTotal.apply(pd.to_numeric, errors='coerce')

# Mostrar los datos
dfLaborForceTotal
# Out:
#                 2010     2011       2012     2013       2014     2015  \
# País
# Panama       1618269  1611450  1689370.0  1744928  1778532.0  1813736
# Costa Rica   2060686  2149242  2321866.0  2337155  2395003.0  2380187
# El Salvador  2494725  2517133  2579866.0  2630753  2617260.0  2618193
# Guatemala    5253574  5486770  5980602.0  5682211  5883588.0  6022488
# Honduras     3260247  3243536  3268694.0  3613486  3810624.0  3919626
# Nicaragua    2442683  2512841  2583025.0  2652874  2722579.0  2784302
# Belize        128753   133836   138977.0   144234   151065.0   156821
#
#                 2016     2017     2018     2019     2020     2021     2022
# País
# Panama       1859078  1885561  1966334  2041466  1929211  1996749  2049663
# Costa Rica   2296246  2335223  2459739  2573190  2456537  2529009  2542517
# El Salvador  2673318  2687119  2694155  2762085  2632889  2768977  2835063
# Guatemala    6184488  6364813  6472399  6481136  6460734  6764382  7069008
# ...

# %%
#cambiar filas por columnas de un dataframe
dfLaborForceTotal.T
# Out:
# País     Panama  Costa Rica  El Salvador  Guatemala   Honduras  Nicaragua  \
# 2010  1618269.0   2060686.0    2494725.0  5253574.0  3260247.0  2442683.0
# 2011  1611450.0   2149242.0    2517133.0  5486770.0  3243536.0  2512841.0
# 2012  1689370.0   2321866.0    2579866.0  5980602.0  3268694.0  2583025.0
# 2013  1744928.0   2337155.0    2630753.0  5682211.0  3613486.0  2652874.0
# 2014  1778532.0   2395003.0    2617260.0  5883588.0  3810624.0  2722579.0
# 2015  1813736.0   2380187.0    2618193.0  6022488.0  3919626.0  2784302.0
# 2016  1859078.0   2296246.0    2673318.0  6184488.0  3983810.0  2845599.0
# 2017  1885561.0   2335223.0    2687119.0  6364813.0  4161688.0  2907286.0
# 2018  1966334.0   2459739.0    2694155.0  6472399.0  4431793.0  2954104.0
# 2019  2041466.0   2573190.0    2762085.0  6481136.0  4399023.0  2999937.0
# 2020  1929211.0   2456537.0    2632889.0  6460734.0  4206572.0  3024864.0
# 2021  1996749.0   2529009.0    2768977.0  6764382.0  4452659.0  3085985.0
# ...

# %%
import matplotlib.pyplot as plt
dfLaborForceTotalMean = dfLaborForceTotal.T.mean() #cambiamos filas por columnas y calculamos la media de cada país
#grafico de barras
dfLaborForceTotalMean.plot(kind='barh', title='Media de Total de la fuerza laboral ', figsize=(5,5), xlabel='País', ylabel='Media de Total de la fuerza laboral')
# Out:
# <Axes: title={'center': 'Media de Total de la fuerza laboral '}, xlabel='País', ylabel='Media de Total de la fuerza laboral'>

# %%
# Calcular describe() considerando los países en lugar de los años
describe_por_pais = dfLaborForceTotal.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count          mean            std        min        25%  \
# País
# Panama        13.0  1.844950e+06  150762.909749  1611450.0  1744928.0
# Costa Rica    13.0  2.372046e+06  149165.010596  2060686.0  2321866.0
# El Salvador   13.0  2.654734e+06   97457.848777  2494725.0  2617260.0
# Guatemala     13.0  6.162015e+06  512823.608716  5253574.0  5883588.0
# Honduras      13.0  3.947438e+06  478615.790309  3243536.0  3613486.0
# Nicaragua     13.0  2.823477e+06  230761.749553  2442683.0  2652874.0
# Belize        13.0  1.587227e+05   18005.699345   128753.0   144234.0
#
#                    50%        75%        max
# País
# Panama       1859078.0  1966334.0  2049663.0
# Costa Rica   2380187.0  2459739.0  2573190.0
# El Salvador  2632889.0  2694155.0  2835063.0
# Guatemala    6184488.0  6472399.0  7069008.0
# Honduras     3983810.0  4399023.0  4564937.0
# Nicaragua    2845599.0  2999937.0  3189118.0
# Belize        162580.0   172620.0   185068.0

# %%
# Transponer para graficar evolución temporal por país
dfLaborForceTotalT = dfLaborForceTotal.T

# Crear el gráfico de líneas
plt.figure(figsize=(12, 6))

for pais in dfLaborForceTotalT.columns:
    plt.plot(dfLaborForceTotalT.index, dfLaborForceTotalT[pais], marker='o', label=pais)

plt.title('Fuerza laboral, total por País (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Fuerza Laboral Total', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# El gráfico de "Labor force, total" nos da una visión clara sobre el tamaño de la fuerza laboral a lo largo del tiempo, lo que nos permite analizar las tendencias económicas, el impacto de las políticas laborales y cómo estos factores afectan la participación de las personas en el mercado laboral. En el contexto de longevidad, un cambio en la fuerza laboral puede estar relacionado con condiciones económicas que afectan la salud, la calidad de vida y, en última instancia, la longevidad de las personas en la región de América Central
#
# **Tendencias en la fuerza laboral :** El gráfico nos permite ver si la fuerza laboral ha crecido, disminuido o permanecido constante en cada país durante el período. Un aumento podría indicar un crecimiento en la población en edad de trabajar o una mayor participación en el mercado laboral.
#
# **Crecimiento económico :** En general, un aumento en el tamaño de la fuerza laboral puede estar relacionado con un crecimiento económico, ya que más personas se integran al mercado laboral. También puede reflejar mejoras en las condiciones laborales o políticas de inclusión.
#
# **Impacto de factores económicos :** Un descenso en la fuerza laboral puede ser un indicador de problemas económicos, como recesión, o de una disminución en la población activa debido a la emigración, el envejecimiento de la población, o la crisis laboral.
#
# **Desigualdad en la participación laboral :**Los países con un crecimiento más pronunciado en su fuerza laboral pueden tener más oportunidades laborales y mejores condiciones socioeconómicas, mientras que aquellos con una disminución podrían enfrentar mayores desafíos en términos de empleo.

# %% [markdown]
# - **Life expectancy at birth, total**: El indicador **"Esperanza de vida al nacer, total (años)"** representa el promedio estimado de años que se espera que viva una persona al nacer, suponiendo que las condiciones de mortalidad actuales permanezcan constantes a lo largo de su vida.

# %%
# seleccionar las filas que contienen el indicador "Esperanza de vida al nacer, total (años)"
dfLifeExpectancy = df[df['Indicador'].str.contains('Life expectancy at birth, total (years)', na=False, regex=False)]


# eliminar la columna indicador
dfLifeExpectancy = dfLifeExpectancy.drop(columns=['Indicador'])

# elegimos la columna "País" como index y eliminamos la columna "País"
dfLifeExpectancy.set_index('País', inplace=True)

# mostrar los datos
dfLifeExpectancy
# Out:
#                2010    2011    2012    2013    2014    2015    2016    2017  \
# País
# Panama       76.448  76.627  76.819  77.038  77.248  77.468  77.653  77.795
# Costa Rica    78.67  79.348  79.283  79.403  78.774  79.086  79.459  79.377
# El Salvador  71.848  71.859  71.831  71.771  71.746  71.814  72.025  72.311
# Guatemala    70.878  71.177  71.463  71.728  71.964  72.103  72.355  72.551
# Honduras     71.088  71.439  71.734  71.963  72.259  72.487  72.588  72.692
# Nicaragua    72.009  72.416  72.615  72.704  72.812  72.983  73.256  73.554
# Belize       72.272  72.651  73.245  73.666  73.311  73.187  73.399  73.562
#
#                2018    2019    2020    2021    2022
# País
# Panama       77.863   77.81  76.657  76.223  76.826
# Costa Rica   79.484  79.427  79.277  77.023   77.32
# El Salvador  72.555  72.559  71.061  70.748  71.475
# Guatemala    72.726  73.129  71.797  69.237  68.674
# Honduras     72.814  72.881  71.462  70.123  70.728
# ...

# %%
# Reemplazar los valores no numéricos por NaN
dfLifeExpectancy.replace('..', pd.NA, inplace=True)

# Convertir los datos a tipo float
dfLifeExpectancy = dfLifeExpectancy.apply(pd.to_numeric, errors='coerce')

# Mostrar los datos
dfLifeExpectancy
# Out:
#                2010    2011    2012    2013    2014    2015    2016    2017  \
# País
# Panama       76.448  76.627  76.819  77.038  77.248  77.468  77.653  77.795
# Costa Rica   78.670  79.348  79.283  79.403  78.774  79.086  79.459  79.377
# El Salvador  71.848  71.859  71.831  71.771  71.746  71.814  72.025  72.311
# Guatemala    70.878  71.177  71.463  71.728  71.964  72.103  72.355  72.551
# Honduras     71.088  71.439  71.734  71.963  72.259  72.487  72.588  72.692
# Nicaragua    72.009  72.416  72.615  72.704  72.812  72.983  73.256  73.554
# Belize       72.272  72.651  73.245  73.666  73.311  73.187  73.399  73.562
#
#                2018    2019    2020    2021    2022
# País
# Panama       77.863  77.810  76.657  76.223  76.826
# Costa Rica   79.484  79.427  79.277  77.023  77.320
# El Salvador  72.555  72.559  71.061  70.748  71.475
# Guatemala    72.726  73.129  71.797  69.237  68.674
# Honduras     72.814  72.881  71.462  70.123  70.728
# ...

# %%
#cambiar filas por columnas de un dataframe
dfLifeExpectancy.T
# Out:
# País  Panama  Costa Rica  El Salvador  Guatemala  Honduras  Nicaragua  Belize
# 2010  76.448      78.670       71.848     70.878    71.088     72.009  72.272
# 2011  76.627      79.348       71.859     71.177    71.439     72.416  72.651
# 2012  76.819      79.283       71.831     71.463    71.734     72.615  73.245
# 2013  77.038      79.403       71.771     71.728    71.963     72.704  73.666
# 2014  77.248      78.774       71.746     71.964    72.259     72.812  73.311
# 2015  77.468      79.086       71.814     72.103    72.487     72.983  73.187
# 2016  77.653      79.459       72.025     72.355    72.588     73.256  73.399
# 2017  77.795      79.377       72.311     72.551    72.692     73.554  73.562
# 2018  77.863      79.484       72.555     72.726    72.814     73.850  73.703
# 2019  77.810      79.427       72.559     73.129    72.881     74.054  73.931
# 2020  76.657      79.277       71.061     71.797    71.462     71.795  72.854
# ...

# %%
import matplotlib.pyplot as plt
dfLifeExpectancyMean = dfLifeExpectancy.T.mean() #cambiamos filas por columnas y calculamos la media de cada país
#grafico de barras
dfLifeExpectancyMean.plot(kind='barh', title='Media de Esperanza de vida al nacer, total', figsize=(5,5), xlabel='País', ylabel='Esperanza de vida al nacer, total (Media en años)')
# Out:
# <Axes: title={'center': 'Media de Esperanza de vida al nacer, total'}, xlabel='País', ylabel='Esperanza de vida al nacer, total (Media en años)'>

# %%
# Calcular describe() considerando los países en lugar de los años
describe_por_pais = dfLifeExpectancy.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count       mean       std     min     25%     50%     75%  \
# País
# Panama        13.0  77.113462  0.562892  76.223  76.657  77.038  77.653
# Costa Rica    13.0  78.917769  0.817523  77.023  78.774  79.283  79.403
# El Salvador   13.0  71.815615  0.518317  70.748  71.746  71.831  72.025
# Guatemala     13.0  71.521692  1.300812  68.674  71.177  71.797  72.355
# Honduras      13.0  71.866000  0.865223  70.123  71.439  71.963  72.588
# Nicaragua     13.0  73.115385  0.836073  71.795  72.615  72.983  73.837
# Belize        13.0  72.862538  1.058816  70.470  72.651  73.245  73.562
#
#                 max
# País
# Panama       77.863
# Costa Rica   79.484
# El Salvador  72.559
# Guatemala    73.129
# Honduras     72.881
# Nicaragua    74.615
# Belize       73.931

# %%
# Transponer para graficar evolución temporal por país
dfLifeExpectancyT = dfLifeExpectancy.T

# Crear el gráfico de líneas
plt.figure(figsize=(12, 6))

for pais in dfLifeExpectancyT.columns:
    plt.plot(dfLifeExpectancyT.index, dfLifeExpectancyT[pais], marker='o', label=pais)

plt.title('Esperanza de vida al nacer, total (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Esperanza de Vida al Nacer (Años)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# El gráfico de "Esperanza de vida al nacer, total" ayuda a visualizar cómo ha cambiado la esperanza de vida de la población de un país o región a lo largo del tiempo. Es un indicador clave para entender el bienestar general de la población, las condiciones de salud y los impactos de las políticas públicas. Este gráfico es esencial para evaluar cómo factores socioculturales, económicos y políticos han influido en la longevidad en la región de América Central entre 2010 y 2022.
#
# **Tendencias en la esperanza de vida :** Este gráfico muestra si la esperanza de vida en un país ha aumentado, disminuido o se ha mantenido estable durante el período analizado. En general, un aumento en la esperanza de vida es una señal de mejoras en la salud pública, la atención médica y las condiciones de vida en general.
#
# **Factores socioeconómicos :** Los países con mayores niveles de esperanza de vida suelen tener mejores sistemas de salud, mejores condiciones socioeconómicas y un acceso más equitativo a servicios básicos. Los países con una esperanza de vida más baja pueden enfrentar desafíos como pobreza, acceso limitado a atención médica o alta mortalidad infantil.
#
# **Desigualdad en la esperanza de vida :** Puede mostrar diferencias notables entre países, incluso dentro de una misma región. Las disparidades en la esperanza de vida pueden estar vinculadas a la desigualdad económica, la calidad del sistema de salud, o factores como el acceso a educación y nutrición.

# %% [markdown]
# ---
# ### Karen
# - **Net migration:** En español, **migración neta**, es el número de inmigrantes menos el número de emigrantes, incluidos ciudadanos y no ciudadanos, durante un período determinado. Si el resultado es negativo, significa que hay una disminución en la cantidad de inmigrantes y un aumento en la cantidad de emigrantes. Si el resultado es positivo, significa que hay un aumento en la cantidad de inmigrantes y una disminución en la cantidad de emigrantes.
#     - Emigrante es aquel que abandona el país del cual es originario para establecerse en uno nuevo en el extranjero.
#     - Inmigrante es aquel que llega a un país distinto de aquel del que es originario con el objetivo de radicarse en él.

# %%
# seleccionar las filas que contienen el indicador "Migración neta"
dfNetMigration = df[df['Indicador'].str.contains('Net migration')]
# Reemplazar ".." por NaN para tratar valores faltantes
dfNetMigration.replace("..", pd.NA, inplace=True)
# Convertir columnas a numérico y calcular la media por país
dfNetMigration.iloc[:, 2:] = dfNetMigration.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# eliminar la columna indicador
dfNetMigration = dfNetMigration.drop(columns=['Indicador'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfNetMigration.set_index('País', inplace=True)
# mostramos los datos
dfNetMigration
# Out:
# C:\Users\familia\AppData\Local\Temp\ipykernel_3880\323735446.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfNetMigration.replace("..", pd.NA, inplace=True)
#                2010    2011     2012    2013     2014    2015    2016    2017  \
# País
# Panama         4953    5167   5447.0    5926   7105.0    8648   10109   11059
# Costa Rica     4728    4258   3983.0    3950   3996.0    4065    4150    4196
# El Salvador  -54686  -53440 -50554.0  -49086 -49130.0  -51282  -47499  -50616
# Guatemala    -36072  -33204 -32572.0  -35666 -40409.0  -48162  -39266  -48049
# Honduras      -5418   -5664  -5896.0   -6094  -6302.0   -6512   -6685   -6782
# Nicaragua    -29081  -28224 -27388.0  -26589 -25571.0  -24359  -23081  -21841
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

for pais in dfNetMigration.index:
    plt.plot(dfNetMigration.columns, dfNetMigration.loc[pais], marker='o', label=pais)

plt.title('Migración neta (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Migración neta (Inmigrantes - Emigrantes)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# El gráfico anterior representa la evolución de la migración neta de la población de cada país centroamericano a través de los años, se puede observar cómo ha incrementado o decrementado la inmigración, y cómo ha decrementado o incrementado la emigración. Cuanto más grande sea la diferencia entre la inmigración y la emigración, más probable es que la población se haya migrado de un país a otro, lo que podría tener implicaciones económicas y sociales en el futuro. Es de tener en cuenta que la migración neta se calcula como la cantidad de inmigrantes menos la cantidad de emigrantes, lo que significa que si el resultado es negativo, hay más personas saliendo de su país de origen que personas entrando a dicho país, mientras que si el resultado es positivo, hay más personas entrando a ese país que personas saliendo a dicho país.
# Por ejemplo, podemos notar que la migración neta de El Salvador se mantiene negativa a lo largo de los años, lo cual indica que la población de El Salvador ha estado emigrando a otros países en los últimos años, mucho más de lo que han inmigrado al país. Si lo comparamos con Panamá, la migración neta es positiva, lo que indica que Panamá ha sido un país que ha tenido una mayor cantidad de inmigrantes que de emigrantes en los últimos años.

# %%
#convertir los datos de tipo objeto a tipo float
dfNetMigration = dfNetMigration.astype(float)
dfNetMigration
# Out:
#                 2010     2011     2012     2013     2014     2015     2016  \
# País
# Panama        4953.0   5167.0   5447.0   5926.0   7105.0   8648.0  10109.0
# Costa Rica    4728.0   4258.0   3983.0   3950.0   3996.0   4065.0   4150.0
# El Salvador -54686.0 -53440.0 -50554.0 -49086.0 -49130.0 -51282.0 -47499.0
# Guatemala   -36072.0 -33204.0 -32572.0 -35666.0 -40409.0 -48162.0 -39266.0
# Honduras     -5418.0  -5664.0  -5896.0  -6094.0  -6302.0  -6512.0  -6685.0
# Nicaragua   -29081.0 -28224.0 -27388.0 -26589.0 -25571.0 -24359.0 -23081.0
# Belize        1644.0   1583.0   1529.0   1504.0   1452.0   1363.0   1283.0
#
#                 2017     2018     2019     2020     2021     2022
# País
# Panama       11059.0  11130.0  10623.0   5473.0   5473.0   7967.0
# Costa Rica    4196.0   4198.0   4154.0   2084.0   2084.0   3850.0
# El Salvador -50616.0 -54158.0 -55143.0 -25214.0 -27343.0 -23249.0
# Guatemala   -48049.0 -56884.0 -58095.0 -23142.0 -29118.0  -9128.0
# ...

# %%
#cambiar filas por columnas de un dataframe
dfNetMigration_T = dfNetMigration.T
dfNetMigration
# Out:
#                 2010     2011     2012     2013     2014     2015     2016  \
# País
# Panama        4953.0   5167.0   5447.0   5926.0   7105.0   8648.0  10109.0
# Costa Rica    4728.0   4258.0   3983.0   3950.0   3996.0   4065.0   4150.0
# El Salvador -54686.0 -53440.0 -50554.0 -49086.0 -49130.0 -51282.0 -47499.0
# Guatemala   -36072.0 -33204.0 -32572.0 -35666.0 -40409.0 -48162.0 -39266.0
# Honduras     -5418.0  -5664.0  -5896.0  -6094.0  -6302.0  -6512.0  -6685.0
# Nicaragua   -29081.0 -28224.0 -27388.0 -26589.0 -25571.0 -24359.0 -23081.0
# Belize        1644.0   1583.0   1529.0   1504.0   1452.0   1363.0   1283.0
#
#                 2017     2018     2019     2020     2021     2022
# País
# Panama       11059.0  11130.0  10623.0   5473.0   5473.0   7967.0
# Costa Rica    4196.0   4198.0   4154.0   2084.0   2084.0   3850.0
# El Salvador -50616.0 -54158.0 -55143.0 -25214.0 -27343.0 -23249.0
# Guatemala   -48049.0 -56884.0 -58095.0 -23142.0 -29118.0  -9128.0
# ...

# %%
# Calcular describe() considerando los países
describe_por_pais = dfNetMigration.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count          mean           std      min      25%      50%  \
# País
# Panama        13.0   7621.538462   2428.017354   4953.0   5473.0   7105.0
# Costa Rica    13.0   3822.769231    800.191972   2084.0   3950.0   4065.0
# El Salvador   13.0 -45492.307692  11785.794694 -55143.0 -53440.0 -50554.0
# Guatemala     13.0 -37674.384615  13433.673006 -58095.0 -48049.0 -36072.0
# Honduras      13.0  -6155.615385    496.923961  -6782.0  -6550.0  -6199.0
# Nicaragua     13.0 -21182.615385   7201.769222 -29081.0 -26589.0 -23081.0
# Belize        13.0   1162.000000    484.149254      0.0   1164.0   1283.0
#
#                  75%      max
# País
# Panama       10109.0  11130.0
# Costa Rica    4196.0   4728.0
# El Salvador -47499.0 -23249.0
# Guatemala   -32572.0  -9128.0
# Honduras     -5779.0  -5374.0
# Nicaragua   -19733.0  -8000.0
# Belize        1504.0   1644.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


dfNetMigration = dfNetMigration.T.mean()#cambiamos filas por columnas y calculamos la media de cada país

plt.figure(figsize=(10, 5))
sns.barplot(y=dfNetMigration.index, x=dfNetMigration)

plt.title('Media de Migración neta', fontsize=14)
plt.ylabel('País', fontsize=12)
plt.xlabel('Migración neta', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %% [markdown]
# El gráfico anterior nos muestra la media de la migración neta de cada país centroamericano. Aquí podemos comprobar que en El Salvador, Guatemala, Honduras y Nicaragua, la migración neta es mayor, pero es negativa, lo que implica que la emigración es mucho más grande que la inmigración. Por otro lado, en Panamá, Costa Rica y Belice, la migración neta es positiva, lo que implica que la emigración es mucho más pequeña que la inmigración. Esto puede deberse a varias razones, como la presencia de ciudades y pueblos en cada país, la disponibilidad de recursos y la capacidad de los gobiernos para manejar la migración.
#
# En general, la migración neta es una medida importante para evaluar la eficacia de la política de inmigración y emigración en un país. Sin embargo, es importante tener en cuenta que la migración neta no es la única medida de eficacia y que existen otras variables que deben ser consideradas, como la disponibilidad de recursos, la capacidad de los gobiernos para manejar la migración, la presencia de ciudades y pueblos, entre otros.

# %% [markdown]
# - 	**People using at least basic sanitation services (% of population):** **Porcentaje de personas que utilizan al menos servicios básicos de saneamiento**, es decir, instalaciones de saneamiento mejoradas que no se comparten con otros hogares. Este indicador abarca tanto a las personas que utilizan servicios básicos de saneamiento como a las que utilizan servicios de saneamiento gestionados de forma segura. Las instalaciones de saneamiento mejoradas incluyen el lavado y vertido de descarga a los sistemas de alcantarillado por tuberías, fosas sépticas o letrinas de pozo; Letrinas de pozo mejoradas ventiladas, inodoros de composición o letrinas de pozo con losas.

# %%
# seleccionar las filas que contienen el indicador "Personas que utilizan al menos servicios básicos de saneamiento (% de la población)"
dfBasicSanServices = df[df['Indicador'].str.contains('basic sanitation services')]
# Convertir columnas a numérico
dfBasicSanServices.iloc[:, 2:] = dfBasicSanServices.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# eliminar la columna indicador
dfBasicSanServices = dfBasicSanServices.drop(columns=['Indicador'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfBasicSanServices.set_index('País', inplace=True)
# mostramos los datos
dfBasicSanServices
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# País
# Panama       72.964141  74.090213  75.224067  76.365718  77.515452  78.672737
# Costa Rica   95.922032  96.169038  96.406732  96.635596  96.856159  97.069017
# El Salvador  83.754774  84.128008  84.492976  84.849751  85.198961  85.540793
# Guatemala    65.369883  65.716311  66.053593  66.384806  66.709880  67.029272
# Honduras     74.039544  74.960123  75.870362  76.769845  77.659178  78.537895
# Nicaragua    66.942099  67.927325  68.911160  69.893603  70.874437  71.853883
# Belize       85.627708  85.942238  86.257854  86.574759  86.893045  87.212981
#
#                   2016       2017       2018       2019       2020       2021  \
# País
# Panama       79.837588  81.010299  82.190613  83.378552  84.573853  85.776812
# Costa Rica   97.274682   97.47361  97.666308  97.853222  98.034809  98.211466
# El Salvador  85.873731  86.197858  86.513661  86.821606  87.121986  87.391507
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

for pais in dfBasicSanServices.index:
    plt.plot(dfBasicSanServices.columns, dfBasicSanServices.loc[pais], marker='o', label=pais)

plt.title('Personas que utilizan al menos servicios básicos de saneamiento (% de la población) (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('% de la población', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# Podemos observar en el gráfico de arriba que el porcentaje de población que tiene acceso a servicios sanitarios básicos en Costa Rica es mayor por mucho en comparación con otros países de la región, se mantiene arriba del 95% a lo largo del tiempo. Mientras que en Guatemela, el porcentaje de población que tiene acceso a servicios sanitarios básicos es menor por mucho en comparación con otros países de la región, desde el 2010 hasta el año 2022 se mantiene por debajo del 70%. Esto sugiere que la situación de acceso a servicios sanitarios básicos en Costa Rica y Guatemala es muy diferente, y que esto puede tener implicaciones para la prevención y el control de la enfermedad en ambos países. Las razones de esto pueden variar, por ejemplo la disponibilidad de recursos humanos, la infraestructura existente, la legislación y la política de gobierno. En general, es importante tener en cuenta que los datos y análisis de los países pueden ser diferentes y que es necesario considerar estos factores cuando se compara la situación de acceso a servicios sanitarios básicos entre diferentes países.

# %%
# Reemplazar los valores .. por 0 para que sea compatible con el cálculo de la media
dfBasicSanServices.replace('NaN', 0, inplace=True)
dfBasicSanServices
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# País
# Panama       72.964141  74.090213  75.224067  76.365718  77.515452  78.672737
# Costa Rica   95.922032  96.169038  96.406732  96.635596  96.856159  97.069017
# El Salvador  83.754774  84.128008  84.492976  84.849751  85.198961  85.540793
# Guatemala    65.369883  65.716311  66.053593  66.384806  66.709880  67.029272
# Honduras     74.039544  74.960123  75.870362  76.769845  77.659178  78.537895
# Nicaragua    66.942099  67.927325  68.911160  69.893603  70.874437  71.853883
# Belize       85.627708  85.942238  86.257854  86.574759  86.893045  87.212981
#
#                   2016       2017       2018       2019       2020       2021  \
# País
# Panama       79.837588  81.010299  82.190613  83.378552  84.573853  85.776812
# Costa Rica   97.274682   97.47361  97.666308  97.853222  98.034809  98.211466
# El Salvador  85.873731  86.197858  86.513661  86.821606  87.121986  87.391507
# ...

# %%
#convertir todos los datos tipo float
dfBasicSanServices = dfBasicSanServices.astype(float)
#reemplazar los valores nulos en la fila 'Nicaragua' por el promedio de los datos de esta
dfBasicSanServices.replace(0, dfBasicSanServices.iloc[5].mean(), inplace=True)
dfBasicSanServices
# Out:
#                   2010       2011       2012       2013       2014       2015  \
# País
# Panama       72.964141  74.090213  75.224067  76.365718  77.515452  78.672737
# Costa Rica   95.922032  96.169038  96.406732  96.635596  96.856159  97.069017
# El Salvador  83.754774  84.128008  84.492976  84.849751  85.198961  85.540793
# Guatemala    65.369883  65.716311  66.053593  66.384806  66.709880  67.029272
# Honduras     74.039544  74.960123  75.870362  76.769845  77.659178  78.537895
# Nicaragua    66.942099  67.927325  68.911160  69.893603  70.874437  71.853883
# Belize       85.627708  85.942238  86.257854  86.574759  86.893045  87.212981
#
#                   2016       2017       2018       2019       2020       2021  \
# País
# Panama       79.837588  81.010299  82.190613  83.378552  84.573853  85.776812
# Costa Rica   97.274682  97.473610  97.666308  97.853222  98.034809  98.211466
# El Salvador  85.873731  86.197858  86.513661  86.821606  87.121986  87.391507
# ...

# %%
# Calcular describe() considerando los países
describe_por_pais = dfBasicSanServices.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count       mean       std        min        25%        50%  \
# País
# Panama        13.0  79.806148  4.416047  72.964141  76.365718  79.837588
# Costa Rica    13.0  97.227407  0.796610  95.922032  96.635596  97.274682
# El Salvador   13.0  85.802953  1.261204  83.754774  84.849751  85.873731
# Guatemala     13.0  67.359936  1.307140  65.369883  66.384806  67.342132
# Honduras      13.0  79.335064  3.364132  74.039544  76.769845  79.406478
# Nicaragua     11.0  71.001849  2.253066  66.942099  69.402381  71.853883
# Belize        13.0  87.306299  0.956989  85.627708  86.574759  87.534777
#
#                    75%        max
# País
# Panama       83.378552  85.879876
# Costa Rica   97.853222  98.383622
# El Salvador  86.821606  87.552784
# Guatemala    68.243669  69.621728
# Honduras     81.952553  84.396991
# Nicaragua    72.897698  73.021098
# Belize       88.198504  88.251078

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dfBasicSanServices = dfBasicSanServices.T.mean() #cambiamos filas por columnas y calculamos la media de cada país

plt.figure(figsize=(10, 5))
sns.barplot(y=dfBasicSanServices.index, x=dfBasicSanServices)

plt.title('Media de Personas que utilizan al menos servicios básicos de saneamiento (% de la población)', fontsize=14)
plt.ylabel('País', fontsize=12)
plt.xlabel('(% de la población)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %% [markdown]
# En este gráfico podemos comparar los promedios de porcentaje de población que tiene acceso a servicios sanitarios básicos en cada país, comprobamos que Costa Rica tiene el mayor porcentaje de población con acceso a servicios sanitarios básicos, y que por tanto tiene la mayor cantidad de población con acceso a servicios sanitarios básicos en la región centroamericana. Mientras que en países como Nicaragua, Guatemala y Honduras, aún les falta cubrir un buen porcentaje de la población con acceso a servicios sanitarios básicos.

# %% [markdown]
# - **Population density (people per sq. km of land area):** En español, **Densidad de población (personas por km² de superficie terrestre)**. La densidad de población se calcula dividiendo la población a mitad de año por la superficie terrestre en kilómetros cuadrados

# %%
# seleccionar las filas que contienen el indicador "Densidad de población (personas por km² de superficie terrestre)"
dfPopulationDensity = df[df['Indicador'].str.contains('Population density')]
# Convertir columnas a numérico
dfPopulationDensity.iloc[:, 2:] = dfPopulationDensity.iloc[:, 2:].apply(pd.to_numeric, errors='coerce')
# eliminar la columna indicador y la columna "2022" porque no tiene ningún dato
dfPopulationDensity = dfPopulationDensity.drop(columns=['Indicador', '2022'])
# elegimos la columna "País" como index y eliminamos la columna "País"
dfPopulationDensity.set_index('País', inplace=True)
# mostramos los datos
dfPopulationDensity
# Out:
#                    2010        2011        2012        2013        2014  \
# País
# Panama        48.743839   49.618967   50.509309   51.406457   52.466176
# Costa Rica    90.525891   91.655425   92.765237   93.841265   94.874422
# El Salvador  295.078861  296.204102  297.359508  298.534846  299.687548
# Guatemala    133.069121  135.512458  137.942721  140.388027  142.836096
# Honduras      75.528939   77.062329   78.580454   80.084521   81.578747
# Nicaragua     48.659914   49.381361   50.113071   50.850748   51.592787
# Belize        14.121263   14.447085   14.776808   15.111267   15.446515
#
#                    2015        2016        2017        2018        2019  \
# País
# Panama        53.387736   54.321856   55.262588   56.150647    57.05759
# Costa Rica    95.872346   96.850862   97.803408   98.721778   99.579553
# El Salvador  300.727124  301.665541  302.444691  302.912259  303.099276
# Guatemala    145.272667  147.701474  150.125215  152.547126  154.946118
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

for pais in dfPopulationDensity.index:
    plt.plot(dfPopulationDensity.columns, dfPopulationDensity.loc[pais], marker='o', label=pais)

plt.title('Densidad poblacional (2010-2022)', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Densidad poblacional', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='País')
plt.grid(alpha=0.4)
plt.show()

# %% [markdown]
# El gráfico nos muestra la evolución de la densidad poblacional en cada país a través de los años. Podemos notar que el país con mayor densidad poblacional es, por mucho, El Salvador, teniendo que entre los años 2010 a 2022 viven aproximadamente 295 a 304 personas por cada km². Esto puede indicar que hay o puede haber una sobrepoblación en este país, ya que el área territorial de El Salvador es de 21,041 km² y su densidad poblacional es alta en comparación con la densidad de población del resto de países de la región centroamericana, quienes tienen más área territorial. Mientras que en otros países, como Belice, Nicaragua y Panamá, la densidad poblacional es mucho menor, lo que sugiere que hay una baja población en estos países. En general, es importante tener en cuenta la densidad poblacional para entender la evolución de la población en un país determinado.

# %%
# Reemplazar los valores .. por 0 para que sea compatible con el cálculo de la media
dfPopulationDensity.replace('NaN', 0, inplace=True)
dfPopulationDensity
# Out:
#                    2010        2011        2012        2013        2014  \
# País
# Panama        48.743839   49.618967   50.509309   51.406457   52.466176
# Costa Rica    90.525891   91.655425   92.765237   93.841265   94.874422
# El Salvador  295.078861  296.204102  297.359508  298.534846  299.687548
# Guatemala    133.069121  135.512458  137.942721  140.388027  142.836096
# Honduras      75.528939   77.062329   78.580454   80.084521   81.578747
# Nicaragua     48.659914   49.381361   50.113071   50.850748   51.592787
# Belize        14.121263   14.447085   14.776808   15.111267   15.446515
#
#                    2015        2016        2017        2018        2019  \
# País
# Panama        53.387736   54.321856   55.262588   56.150647    57.05759
# Costa Rica    95.872346   96.850862   97.803408   98.721778   99.579553
# El Salvador  300.727124  301.665541  302.444691  302.912259  303.099276
# Guatemala    145.272667  147.701474  150.125215  152.547126  154.946118
# ...

# %%
#convertir todos los datos tipo float
dfPopulationDensity = dfPopulationDensity.astype(float)
#reemplazar los valores nulos en la fila 'Nicaragua' por el promedio de los datos de esta
dfPopulationDensity.replace(0, dfPopulationDensity.iloc[5].mean(), inplace=True)
dfPopulationDensity
# Out:
#                    2010        2011        2012        2013        2014  \
# País
# Panama        48.743839   49.618967   50.509309   51.406457   52.466176
# Costa Rica    90.525891   91.655425   92.765237   93.841265   94.874422
# El Salvador  295.078861  296.204102  297.359508  298.534846  299.687548
# Guatemala    133.069121  135.512458  137.942721  140.388027  142.836096
# Honduras      75.528939   77.062329   78.580454   80.084521   81.578747
# Nicaragua     48.659914   49.381361   50.113071   50.850748   51.592787
# Belize        14.121263   14.447085   14.776808   15.111267   15.446515
#
#                    2015        2016        2017        2018        2019  \
# País
# Panama        53.387736   54.321856   55.262588   56.150647   57.057590
# Costa Rica    95.872346   96.850862   97.803408   98.721778   99.579553
# El Salvador  300.727124  301.665541  302.444691  302.912259  303.099276
# Guatemala    145.272667  147.701474  150.125215  152.547126  154.946118
# ...

# %%
# Calcular describe() considerando los países
describe_por_pais = dfPopulationDensity.T.describe().T

# Mostrar el resultado
print(describe_por_pais)
# Out:
#              count        mean       std         min         25%         50%  \
# País
# Panama        12.0   53.789579  3.308987   48.743839   51.182170   53.854796
# Costa Rica    12.0   96.147035  3.469013   90.525891   93.572258   96.361604
# El Salvador   12.0  300.512898  3.136483  295.078861  298.241011  301.196332
# Guatemala     12.0  146.443809  8.735849  133.069121  139.776701  146.487071
# Honduras      12.0   83.778889  5.361578   75.528939   79.708504   83.811346
# Nicaragua     12.0   52.744935  2.709927   48.659914   50.666329   52.716607
# Belize        12.0   15.905728  1.145770   14.121263   15.027652   15.940026
#
#                     75%         max
# País
# Panama        56.377383   58.658223
# Costa Rica    98.936222  100.939228
# El Salvador  302.959013  304.737790
# Guatemala    153.146874  159.665416
# Honduras      87.892973   91.861158
# Nicaragua     54.804352   56.926541
# Belize        16.826973   17.537527

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dfPopulationDensity = dfPopulationDensity.T.mean() #cambiamos filas por columnas y calculamos la media de cada país

plt.figure(figsize=(10, 5))
sns.barplot(y=dfPopulationDensity.index, x=dfPopulationDensity)

plt.title('Media de Densidad de población (personas por km² de superficie terrestre)', fontsize=14)
plt.ylabel('País', fontsize=12)
plt.xlabel('Densidad de población (personas por km²)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %% [markdown]
# En este gráfico de barras se muestra el promedio de densidad poblacional de cada país, podemos comprobar que el país con mayor densidad poblacional es El Salvador, con una densidad poblacional promedio de 300 personas por km², aproximadamente. En el resto de países se observan distribuciones con densidades poblacionales menores, por ejemplo, en Guatemala con una densidad poblacional de 146 personas por km², y en Honduras con una densidad poblacional de 83 personas por km². Estas diferencias en la distribución poblacional pueden tener un impacto significativo en la forma en que se comportan las personas en el país, ya que las personas con menor densidad poblacional tienden a vivir en zonas más pobres y menos accesibles, mientras que las personas con mayor densidad poblacional tienden a vivir en zonas más ricas y accesibles. Aunque en ocasiones, esto no necesariamente significa que las personas con mayor densidad poblacional son más vulnerables a la pobreza, pues la pobreza puede afectar a la distribución poblacional en diferentes maneras, como la falta de acceso a servicios básicos como agua potable y educación. En general, es importante considerar la distribución poblacional cuando se está analizando la pobreza y la vulnerabilidad de las personas en un país.

# %% [markdown]
# ---
#
# ## Conclusiones Finales
# - **Esperanza de vida al nacer, total (Esperanza de vida al nacer)**
# Conclusión : La esperanza de vida al nacer en los países de América Central ha mostrado una tendencia general de aumento entre 2010 y 2022, lo que refleja mejoras en los sistemas de salud, las condiciones de vida y el acceso a servicios básicos. Sin embargo, las disparidades entre países son notorias, con algunos países experimentando aumentos más pronunciados debido a políticas de salud pública más efectivas y mejor acceso a servicios médicos. Estos aumentos pueden atribuirse a factores como la mejora de la atención prenatal, la reducción de enfermedades transmisibles y el acceso creciente a tecnología médica, lo que contribuye significativamente a una mayor longevidad.
#
# - **Fuerza laboral, total (Fuerza laboral total)**
# Conclusión : El tamaño de la fuerza laboral en América Central ha experimentado un crecimiento en la última década, especialmente en países con una población joven y en crecimiento. Este crecimiento está relacionado con cambios económicos que promueven la inclusión laboral, la urbanización y la mejora de la educación. Sin embargo, las desigualdades en la participación laboral entre los diferentes países de la región evidencian la existencia de retos socioeconómicos, como el desempleo, la informalidad laboral y la falta de empleos de calidad, lo que afecta indirectamente la longevidad. La integración de más personas a la fuerza laboral también tiene efectos en la salud mental y física de los trabajadores, lo que impacta su esperanza de vida.
#
# - **Fuerza laboral con educación avanzada**
# Conclusión : La fuerza laboral con educación avanzada ha crecido en algunos países de América Central, impulsada por mejoras en el acceso a la educación superior y políticas que fomentan la formación profesional. Esto refleja un cambio positivo hacia una economía más orientada al conocimiento y con mayores oportunidades de empleo cualificado, lo cual tiene una relación directa con un aumento en la calidad de vida y la longevidad. Sin embargo, aún existen grandes desafíos en cuanto a la equidad en el acceso a educación avanzada, lo que perpetúa las disparidades entre sectores socioeconómicos y países dentro de la región. La educación avanzada contribuye no solo a mejorar las perspectivas económicas, sino también a una mayor conciencia sobre estilos de vida saludables, lo que, a su vez, puede mejorar la longevidad.

# %% [markdown]
# - **PIB per cápita y esperanza de vida**: Los países con un mayor PIB per cápita, como Panamá y Costa Rica, tienden a tener una esperanza de vida más alta. Esto se debe a que un mayor ingreso nacional suele estar relacionado con mejores servicios de salud, educación, y calidad de vida en general.
# Por otro lado, países como El Salvador, Nicaragua y Belice, que tienen un PIB per cápita más bajo, presentan una esperanza de vida menor, aunque las diferencias no son tan marcadas, lo que indica que otros factores también influyen.
#
# - **Porcentaje de industrialización y esperanza de vida**: Países como El Salvador y Guatemala, que tienen porcentajes más altos de industrialización, muestran una esperanza de vida competitiva, aunque no necesariamente al nivel de Panamá y Costa Rica. Esto sugiere que, si bien la industrialización contribuye al desarrollo económico, no siempre tiene un impacto directo e inmediato en indicadores como la esperanza de vida.
# Costa Rica, a pesar de una disminución en su porcentaje de industrialización, mantiene una esperanza de vida alta, posiblemente debido a su enfoque en sectores como servicios y turismo, y su inversión en salud pública y bienestar.

# %% [markdown]
# - **Promedio de acceso a electricidad por país (% de población):** El acceso a la electricidad podría llegar a afectar en la esperanza de vida, ya que la disponibilidad de electricidad está relacionada con el desarrollo de la infraestructura básica y la mejora de las condiciones de vida. Sin embargo en base a los graficos obtenidos se concluye que no es un factor determinante debido a la disparidad de resultados al comparar los graficos de esperanza de vida y acceso a la electricidad, por ejemplo, Nicaragua tiene mayor esperanza de vida que Honduras y Guatemala a pesar que ambos tienen mayor porcentaje de acceso a la electricidad.
#
# - **Ingreso nacional neto ajustado per cápita ($):** El ingreso nacional neto ajustado per cápita está estrechamente relacionado con la esperanza de vida, ya que refleja el nivel económico de un país y su capacidad para ofrecer servicios de salud, educación y bienestar social a su población. Los países con un mayor ingreso, como Panamá y Costa Rica, presentan una mayor esperanza de vida, lo que está en línea con la disponibilidad de recursos para mejorar la salud pública, la seguridad social y las condiciones de vida. En contraste, los países con ingresos más bajos, como Nicaragua y Honduras, tienden a tener una esperanza de vida más baja, lo que indica que un mayor desarrollo económico puede contribuir significativamente a la longevidad de la población, proporcionando mejores condiciones para el acceso a servicios básicos y cuidados médicos.

# %% [markdown]
# - **Net migration:** La migración neta representa la resta de la cantidad de inmigrantes menos la cantidad de emigrantes. Por lo que si hay un aumento en la cantidad de emigrantes de un país, esto se reflejará en una cantidad negativa de migración neta. En países como El Salvador y Guatemala, la migración neta se ha mantenido negativa y decayendo cada vez más, lo que puede indicar que las condiciones de vida en esos países empeoraban con el tiempo y la población buscaba salir de su país de origen, solo es hasta el año 2019 que se puede observar un aumento de la migración neta de esos países, lo que sugiere que las condiciones de vida en esos países han mejorado y hay menos emigrantes. La esperanza de vida en El Salvador se ha mantenido entre los 70 y los 72 años, mientras que en Guatemala la esperanza de vida se mantiene entre los 68 y los 73 años. Si comparamos la esperanza de vida de estos dos países con la de Costa Rica y Panamá, podemos ver que es un poco mayor, en Panamá ronda los 76 a 77 años y en Costa Rica ronda los 77 a 79 años. Si observamos la evolución de la migración neta entre 2010 y 2022, podemos ver que en Guatemala y El Salvador hay una fuerte fuerza de emigración, mientras que en Costa Rica y Panamá es mayor la inmigración, puede deberse a que la calidad de la vida en estos países es mejor que en otros países de la región.
#
# - **People using at least basic sanitation services (% of population):** En cuanto a este indicador, quienes mejor cubren los hogares con acceso a servicios de saneamiento básico son Costa Rica que se mantiene entre el 95.9% y 98.4% aproximadamente, tomando en cuenta que es uno de los países con mejor esperanza de vida y mayor inmigración en la región, podríamos deducir que la calidad de la vida en Costa Rica es mejor que en otros países de la región, ya que contar con servicios de saneamiento básico previene la contaminación de agua y la salud de los ciudadanos, además de evitar posibles enfermedades debidas a la exposición a desechos del cuerpo humano. En contraste, Guatemala que se mantiene entre 65.4% y 69.6% aproximadamente, es uno de los países con menor esperanza de vida y mayor emigración en la región, podríamos deducir que la calidad de la vida en Guatemala no es tan buena como en otros países de la región.
#
# - **Population density (people per sq. km of land area):** La densidad poblacional es una medida importante de la población de un país, ya que indica la cantidad de personas que viven en un área determinada. En El Salvador, la cantidad de personas viviendo por km² es por mucho mayor a la de otros países de la región, siendo de entre 295 a 304 personas por km² aproximadamente, en comparación con Honduras, Nicaragua, Panamá y Belice, que mantienen densidades poblacionales por debajo de las 100 personas por km², tomando en cuenta que sus territorios son mucho mayores que el de El Salvador (excepto por Belice, que es solo un poco más grande). En cuanto a densidad poblacional es Costa Rica quien se mantiene más equilibrado, podemos decir que la población de Costa Rica es mucho más equilibrada que en otros países de la región y que sus condiciones de vida son mejores que en otros países de la región.

# %% [markdown]
# - **Gasto sanitario corriente per cápita (US$ corrientes):** El gasto sanitario corriente per cápita en Centroamérica presenta una variabilidad considerable entre los países, en general, países como Costa Rica y Panamá tienden a tener un gasto significativamente mayor en comparación con países como Honduras o Nicaragua. Esto refleja mayores inversiones en sistemas de salud, mejor acceso a servicios médicos y una mayor capacidad para financiar la atención sanitaria.
# La desigualdad en el gasto puede estar asociada a diferencias en el desarrollo económico, políticas de salud pública y prioridades gubernamentales.
#
# - **Ratio empleo/población, 15+, total (%) (estimación nacional):** El ratio empleo/población refleja la proporción de la población en edad de trabajar que está empleada, y en Centroamérica también se observan diferencias significativas: países como Guatemala y Honduras suelen registrar ratios de empleo más altos debido a una mayor participación en actividades informales, agrícolas y comerciales. Sin embargo, un alto ratio no siempre implica empleos de calidad, ya que muchos trabajadores carecen de estabilidad o seguridad laboral. Nicaragua y El Salvador enfrentan desafíos estructurales, como altas tasas de migración laboral y bajo crecimiento económico, lo que limita las oportunidades de empleo formal. Además, el ratio empleo en la región se ve influenciado por factores como la informalidad, la estabilidad política, las inversiones en educación y la creación de empleo de calidad. En si una alta tasa no implica un empleo digno, se debe considerar la posibilidad de que el trabajo no sea suficientemente digno para satisfacer las necesidades de los trabajadores y a su vez como esto afecta a su vida el empezar a trabajar a temprana edad o el emigrar en busca de una mejor calidad de vida.
